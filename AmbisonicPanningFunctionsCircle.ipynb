# %% [markdown]
# # This code example is to demonstrate 2D Ambisonic panning functions interactively
# Acoustic Holography and Holophony
#
# Franz Zotter, 2016
#
#
# ## Ambisonic Panning function in 2D
# The Ambisonic panning function is derived from the equivalence that an infinite Fourier series equals a Dirac delta function:
#
# \begin{equation}
# g_\infty(\varphi)=\sum_{m=-\infty}^\infty e^{\mathrm{i}m(\varphi)}=\sum_{m=0}^\infty(2-\delta_{m,0})\cos(m\varphi)=\delta(\varphi).
# \end{equation}
#
# After making the order finite, we obtain a sinc function
#
# \begin{equation}
# g_\mathrm{N}(\varphi)=\sum_{m=0}^\mathrm{N}(2-\delta_{m,0})\cos(m\varphi)=\frac{\sin[(\mathrm{N}+\frac{1}{2})\varphi]}{\sin(\frac{1}{2}\varphi)}.
# \end{equation}

# %%
import numpy as np
import scipy as sp
import math
from bokeh.plotting import figure, output_file, show
from bokeh.io import push_notebook, output_notebook
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets

phi=np.linspace(-np.pi,np.pi,100)
output_notebook()
p1 = figure(title="5th order periodic sinc function",plot_width=400,plot_height=250)
N=5
normalization=2*N+1
sincp=np.sin((N+0.5)*phi)/np.sin(0.5*phi)
p1.line(phi*180/np.pi,normalization*sincp,line_width=3)
show(p1)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9cc8949e-c48d-476f-9ec5-84919b9a090b">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="36eb115b-2f80-45de-942b-dde51e31786b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#36eb115b-2f80-45de-942b-dde51e31786b").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("36eb115b-2f80-45de-942b-dde51e31786b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '36eb115b-2f80-45de-942b-dde51e31786b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"38047955-d5e9-4838-ab87-a47b7b6b1218":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"808f13c8-c22f-4fc0-a8b1-39417e16b42f","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"6d7fc80e-9e56-4164-ac65-d31725026f7d","subtype":"Figure","type":"Plot"},"ticker":{"id":"3f791aeb-77ad-4640-b491-41f15c7b9171","type":"BasicTicker"}},"id":"dd9c01ab-d976-40de-9ac8-91a22a1dbd3f","type":"Grid"},{"attributes":{"below":[{"id":"5bb7a4ef-138e-4209-86ef-b5bf508a4e8c","type":"LinearAxis"}],"left":[{"id":"94a2daeb-cd08-4c59-90f1-eb59f9fff392","type":"LinearAxis"}],"plot_height":250,"plot_width":400,"renderers":[{"id":"5bb7a4ef-138e-4209-86ef-b5bf508a4e8c","type":"LinearAxis"},{"id":"dd9c01ab-d976-40de-9ac8-91a22a1dbd3f","type":"Grid"},{"id":"94a2daeb-cd08-4c59-90f1-eb59f9fff392","type":"LinearAxis"},{"id":"b7fef881-3c0d-49ab-b10b-92ad42b36935","type":"Grid"},{"id":"808f13c8-c22f-4fc0-a8b1-39417e16b42f","type":"BoxAnnotation"},{"id":"0d67cdd8-2c8b-46e8-a27b-4ad9d28c47c6","type":"GlyphRenderer"}],"title":{"id":"078f333c-831e-47e6-b0e3-55684bc5ae4f","type":"Title"},"tool_events":{"id":"c6fb92a4-395e-4d57-be74-425b949a07da","type":"ToolEvents"},"toolbar":{"id":"cfbe1795-26be-47b5-9de0-c910d03045f4","type":"Toolbar"},"x_range":{"id":"9623e578-0fb9-4249-9885-b2a668c006b6","type":"DataRange1d"},"y_range":{"id":"816d0f64-20ad-4306-b51b-f60a44a6249e","type":"DataRange1d"}},"id":"6d7fc80e-9e56-4164-ac65-d31725026f7d","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":"5th order periodic sinc function"},"id":"078f333c-831e-47e6-b0e3-55684bc5ae4f","type":"Title"},{"attributes":{},"id":"46387178-14e1-4003-8563-749bf4d6f666","type":"BasicTicker"},{"attributes":{"plot":{"id":"6d7fc80e-9e56-4164-ac65-d31725026f7d","subtype":"Figure","type":"Plot"}},"id":"46852ad9-8f39-4301-9b92-6fe04729b186","type":"PanTool"},{"attributes":{},"id":"c6fb92a4-395e-4d57-be74-425b949a07da","type":"ToolEvents"},{"attributes":{},"id":"efd59ad8-3df2-4891-9b1c-580f16139fe1","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"808f13c8-c22f-4fc0-a8b1-39417e16b42f","type":"BoxAnnotation"},"plot":{"id":"6d7fc80e-9e56-4164-ac65-d31725026f7d","subtype":"Figure","type":"Plot"}},"id":"f76921ae-943d-4b9a-b4ca-0b525d497f93","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"9623e578-0fb9-4249-9885-b2a668c006b6","type":"DataRange1d"},{"attributes":{},"id":"a0551f11-69f1-4839-a97c-39d28992b9b4","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"454a968a-fe97-4088-a174-ec38660b5bce","type":"Line"},{"attributes":{"data_source":{"id":"a61494ac-22a8-47a6-b7eb-3aa5667ae3d0","type":"ColumnDataSource"},"glyph":{"id":"73c8542d-9721-4103-ba5e-7269163cb4da","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"454a968a-fe97-4088-a174-ec38660b5bce","type":"Line"},"selection_glyph":null},"id":"0d67cdd8-2c8b-46e8-a27b-4ad9d28c47c6","type":"GlyphRenderer"},{"attributes":{},"id":"3f791aeb-77ad-4640-b491-41f15c7b9171","type":"BasicTicker"},{"attributes":{"plot":{"id":"6d7fc80e-9e56-4164-ac65-d31725026f7d","subtype":"Figure","type":"Plot"}},"id":"58dce71f-197e-482f-85ed-0587e15b8103","type":"WheelZoomTool"},{"attributes":{"formatter":{"id":"a0551f11-69f1-4839-a97c-39d28992b9b4","type":"BasicTickFormatter"},"plot":{"id":"6d7fc80e-9e56-4164-ac65-d31725026f7d","subtype":"Figure","type":"Plot"},"ticker":{"id":"46387178-14e1-4003-8563-749bf4d6f666","type":"BasicTicker"}},"id":"94a2daeb-cd08-4c59-90f1-eb59f9fff392","type":"LinearAxis"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"fiel ...

# %% [markdown]
# This kind of periodic sinc function could be cyclically shifted by any angle $\varphi_\mathrm{s}$ and would not change its shape. However, we are not quite satisfied with the height of its sidelobes. It is worth to involve weights $a_m$ for the suppression of these sidelobes:
#
# \begin{equation}
#    g_\mathrm{N}(\varphi)=\sum_{m=0}^\mathrm{N}a_m\,(2-\delta_{m,0})\cos(m\varphi).
# \end{equation}
#
# The so-called in-phase weighting (see Jérôme Daniel et al 1999) is defined as
#
# \begin{equation}
#    a_m=\frac{N!^2}{(N-m)!(N+m)!}=\frac{N^\underline{m}}{N^\overline{m}},
# \end{equation}
#
# and the so-called max-$\boldsymbol{r}_\mathrm{E}$ weighting is
#
# \begin{equation}
#    a_m=\cos\Bigl(\frac{\pi}{2(\mathrm{N}+1)}\Bigr),
# \end{equation}
#
# and the neutral,rectangular weighting with $a_m=1$ is called basic.

# %%
def inphase_weights(N):
    a=np.ones(N+1)
    for n in range(1,N+1):
        a[n]=(N-n+1)/(1.0*(N+n))*a[n-1]
    return a

def maxre_weights(N):
    m=np.arange(0,N+1)
    a=np.cos(np.pi/(2*(N+1))*m)
    return a

def basic_weights(N):
    a=np.ones(N+1)
    return a

N=7
p2 = figure(title="7th-order weights",plot_width=400,plot_height=250)
m=np.arange(0,N+1)
a=basic_weights(N)
p2.line(m,a,color="green",line_width=3,legend="basic")
a=inphase_weights(N)
p2.line(m,a,color="red",line_width=3,legend="in-phase")
a=maxre_weights(N)
p2.line(m,a,color="blue",line_width=3,legend="max-rE")
p2.legend.background_fill_alpha=0.4
show(p2)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="
type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"green"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"e57c7e93-7274-4706-8b1c-fbf972241c9d","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"5d031d06-00fb-409f-a3cd-1f3ce67cb6a5","type":"Line"},{"attributes":{"formatter":{"id":"d17e2483-620a-4eaf-8272-dd7901af7f69","type":"BasicTickFormatter"},"plot":{"id":"a565fc67-a310-45d8-b5ed-a79d4952b074","subtype":"Figure","type":"Plot"},"ticker":{ ...

# %%
def weighted_cosine_series(phi,a):
    N=a.size-1
    g=np.zeros(phi.size)
    amplitude=0;
    for m in range(0,N+1):
        g+=np.cos(m*phi)*a[m]*(2-(m==0))
        amplitude+=a[m]*(2-(m==0))
    return g/amplitude

p3 = figure(title="weighted cosine series",plot_width=400,plot_height=250)
a=basic_weights(N)
g=weighted_cosine_series(phi,a)
p3.line(phi*180/np.pi,g,line_width=3,color='green',legend="rectangular")
a=inphase_weights(N)
g=weighted_cosine_series(phi,a)
p3.line(phi*180/np.pi,g,line_width=3,color='red',legend="in-phase")
a=maxre_weights(N)
g=weighted_cosine_series(phi,a)
p3.line(phi*180/np.pi,g,line_width=3,color='blue',legend="max-rE")
show(p3)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="0893f097-e7fc-4252-a286-26b67ad9dfd7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#0893f097-e7fc-4252-a286-26b67ad9dfd7").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0893f097-e7fc-4252-a286-26b67ad9dfd7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0893f097-e7fc-4252-a286-26b67ad9dfd7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"69f28389-b466-450b-a954-3a8876a5130e":{"roots":{"references":[{"attributes":{"data_source":{"id":"0191a078-0b44-428b-8a41-497d240815c1","type":"ColumnDataSource"},"glyph":{"id":"89f3b782-30e8-4919-bfb7-9f0bd9b70329","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"d2418056-c12f-49ef-925a-73322c6d9b1e","type":"Line"},"selection_glyph":null},"id":"454585b0-2af3-4cd9-b79f-bcaa4baf058a","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"blue"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"89f3b782-30e8-4919-bfb7-9f0bd9b70329","type":"Line"},{"attributes":{"dimension":1,"plot":{"id":"f5c2e188-ce15-49a8-99df-8b08422df62d","subtype":"Figure","type":"Plot"},"ticker":{"id":"ad12d27e-2565-4a1a-b4c9-94d7d0347cae","type":"BasicTicker"}},"id":"70667b58-493f-4121-8c2e-b58a8044e658","type":"Grid"},{"attributes":{"overlay":{"id":"6cd62d2c-c9bb-4bf6-8d16-f85590311b8a","type":"BoxAnnotation"},"plot":{"id":"f5c2e188-ce15-49a8-99df-8b08422df62d","subtype":"Figure","type":"Plot"}},"id":"7e8366b8-a427-4a3b-8803-c955509418c3","type":"BoxZoomTool"},{"attributes":{"line_color":{"value":"green"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"71176b53-28ad-4cf3-a6a0-b686067fc6a4","type":"Line"},{"attributes":{"data_source":{"id":"92e5cabf-8130-45ae-bbf2-a738df17ae75","type":"ColumnDataSource"},"glyph":{"id":"71176b53-28ad-4cf3-a6a0-b686067fc6a4","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"ba87eb5e-1dc0-4ce7-9e12-9d75498a670f","type":"Line"},"selection_glyph":null},"id":"98d9ba99-dbc3-4e53-8fbb-f824d502b106","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"87f0675b-f349-4da1-af1f-91e1552b5ef6","type":"DataRange1d"},{"attributes":{},"id":"4cff421a-6ad7-41d4-ac04-0a43a26112ed","type":"ToolEvents"},{"attributes":{"below":[{"id":"4ecfd93d-a0d3-49a5-859a-60419424d44f","type":"LinearAxis"}],"left":[{"id":"432a755c-4b76-41a6-a698-c5d75f62454a","type":"LinearAxis"}],"plot_height":250,"plot_width":400,"renderers":[{"id":"4ecfd93d-a0d3-49a5-859a-60419424d44f","type":"LinearAxis"},{"id":"0a43e744-4d88-4c0c-b883-7e1ac98986b0","type":"Grid"},{"id":"432a755c-4b76-41a6-a698-c5d75f62454a","type":"LinearAxis"},{"id":"70667b58-493f-4121-8c2e-b58a8044e658","type":"Grid"},{"id":"6cd62d2c-c9bb-4bf6-8d16-f85590311b8a","type":"BoxAnnotation"},{"id":"3cc376dd-c8f7-40cd-97f5-00d365d2f432","type":"Legend"},{"id":"98d9ba99-dbc3-4e53-8fbb-f824d502b106","type":"GlyphRenderer"},{"id":"96a73039-d1ec-40c6-b80e-ad35b04913a6","type":"GlyphRenderer"},{"id":"454585b0-2af3-4cd9-b79f-bcaa4baf058a","type":"GlyphRenderer"}],"title":{"id":"3365eb61-174e-4bf3-bdbf-daf91f1652a7","type":"Title"},"tool_events":{"id":"4cff421a-6ad7-41d4-ac04-0a43a26112ed","type":"ToolEvents"},"toolbar":{"id":"f774641d-75a4-417f-917f-cb2bca37d8f8","type":"Toolbar"},"x_range":{"id":"df0e4318-c484-4f2a-9646-a521c3a857dc","type":"DataRange1d"},"y_range":{"id":"87f0675b-f349-4da1-af1f-91e1552b5ef6","type":"DataRange1d"}},"id":"f5c2e188-ce15-49a8-99df-8b08422df62d","subtype":"Figure","type":"Plot"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"d2418056-c12f-49ef-925a-73322c6d9b1e","type":"Line"},{"attributes":{"data_source":{"id":"a5b76333-226a-49bd-b35d-35cb0986a893","type":"ColumnDataSource"},"glyph":{"id":"c862313f-a753-4696-afdd-7b641146e675","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"a5b5c16f-7dd4-4739-81cf-1276270f9d8e","type":"Line"},"selection_glyph":null},"id":"96a73039-d1ec-40c6-b80e-ad35b04913a6","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[-180.0,-176.36363636363635,-172.72727272727272,-169.09090909090907,-165.45454545454544,-161.8181818181818,-158.1818181818182,-154.54545454545453,-150.9090909090909,-147.27272727272728,-143.63636363636363,-140.0,-136.36363636363637,-132.72727272727272,-129.09090909090907,-125.4545454545454 ...

# %%
def g_ambipan(N,phis,phi,weight_type):
    g=np.zeros(phi.size)
    ampl=0
    if weight_type == 1:
        a=inphase_weights(N)
    elif weight_type == 2:
        a=maxre_weights(N)
    else:
        a=basic_weights(N)
    g=weighted_cosine_series(phi-phis,a)
    return g

# %%
output_notebook()
g=g_ambipan(5,0,phi,0)
p = figure(title="2D Ambi Panning Function",plot_width=400, plot_height=270, x_range=(-180,180), y_range=(-.4,1.1))
ll=p.line(phi*180/np.pi, g , line_width=3)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="fa663d9e-fba0-4fb0-a5d7-6f587abd051b">Loading BokehJS ...</span>
#     </div>

# %%
def plot_ambipan(N,phis,weight_type):
    phi=np.linspace(-np.pi,np.pi,100)
    g=g_ambipan(N,phis*np.pi/180,phi,weight_type)
    ll.data_source.data['y']=g
    push_notebook()

# %%
show(p,notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="b252eac9-0ad7-4b9c-a396-92029b20125d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#b252eac9-0ad7-4b9c-a396-92029b20125d").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("65aa7270-7c99-40d3-b271-3e983ae1c347", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b252eac9-0ad7-4b9c-a396-92029b20125d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b252eac9-0ad7-4b9c-a396-92029b20125d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"6519be19-b497-4c93-9699-c94d3aa36a63":{"roots":{"references":[{"attributes":{"formatter":{"id":"6d63c259-700e-40ef-894e-7105193397da","type":"BasicTickFormatter"},"plot":{"id":"e0d942a8-acd8-4be1-b795-386689d572cc","subtype":"Figure","type":"Plot"},"ticker":{"id":"1dfc8fe9-a740-4111-b811-d4c8a6dd57d4","type":"BasicTicker"}},"id":"5123b142-4de1-4518-8ad0-f5cb6fb007b8","type":"LinearAxis"},{"attributes":{"below":[{"id":"5123b142-4de1-4518-8ad0-f5cb6fb007b8","type":"LinearAxis"}],"left":[{"id":"89730fe8-056e-46ec-9ffa-605c7bbede8a","type":"LinearAxis"}],"plot_height":270,"plot_width":400,"renderers":[{"id":"5123b142-4de1-4518-8ad0-f5cb6fb007b