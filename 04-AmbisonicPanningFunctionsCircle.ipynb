# %% [markdown]
# # This code example is to demonstrate 2D Ambisonic panning functions interactively
# Acoustic Holography and Holophony
#
# Franz Zotter, 2016
#
#
# ## Ambisonic Panning function in 2D
# The Ambisonic panning function is derived from the equivalence that an infinite Fourier series equals a Dirac delta function:
#
# \begin{equation}
# g_\infty(\varphi)=\sum_{m=-\infty}^\infty e^{\mathrm{i}m(\varphi)}=\sum_{m=0}^\infty(2-\delta_{m,0})\cos(m\varphi)=\delta(\varphi).
# \end{equation}
#
# After making the order finite, we obtain a sinc function
#
# \begin{equation}
# g_\mathrm{N}(\varphi)=\sum_{m=0}^\mathrm{N}(2-\delta_{m,0})\cos(m\varphi)=\frac{\sin[(\mathrm{N}+\frac{1}{2})\varphi]}{\sin(\frac{1}{2}\varphi)}.
# \end{equation}

# %%
import numpy as np
import scipy as sp
import math
from bokeh.plotting import figure, output_file, show
from bokeh.io import push_notebook, output_notebook
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets

phi=np.linspace(-np.pi,np.pi,100)
output_notebook()
p1 = figure(title="5th order periodic sinc function",plot_width=400,plot_height=250)
N=5
normalization=2*N+1
sincp=np.sin((N+0.5)*phi)/np.sin(0.5*phi)
p1.line(phi*180/np.pi,normalization*sincp,line_width=3)
show(p1)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a51b5b89-7cc2-4d51-85ea-3f7513a0d546">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="f33c8a13-6b06-4c88-924c-09526f3cee36"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#f33c8a13-6b06-4c88-924c-09526f3cee36").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f33c8a13-6b06-4c88-924c-09526f3cee36");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f33c8a13-6b06-4c88-924c-09526f3cee36' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"f762ea62-b271-4ded-8434-b19e5e4ebaa5":{"roots":{"references":[{"attributes":{},"id":"a669018a-94e7-479e-a986-8cae59202210","type":"BasicTicker"},{"attributes":{},"id":"57d8db9f-d6ef-49fd-bdec-33b944b8f798","type":"BasicTickFormatter"},{"attributes":{},"id":"199b3c6f-dcf6-415f-bb8c-16af4eab4c93","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"5ec051ed-4587-45b2-9f79-c060763037ea","type":"Line"},{"attributes":{"plot":{"id":"00f7dec9-6357-47c0-81a2-ab301878f229","subtype":"Figure","type":"Plot"}},"id":"0a7d92b8-20be-4859-b4a5-de03832709d0","type":"HelpTool"},{"attributes":{"callback":null},"id":"92977474-b67b-45b2-bcbe-f79b5493e729","type":"DataRange1d"},{"attributes":{},"id":"ecb10ef9-bd48-4b17-8398-2e6968867408","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":"5th order periodic sinc function"},"id":"18a2b765-47f5-44a7-a0a5-30e5f7d08b41","type":"Title"},{"attributes":{"dimension":1,"plot":{"id":"00f7dec9-6357-47c0-81a2-ab301878f229","subtype":"Figure","type":"Plot"},"ticker":{"id":"199b3c6f-dcf6-415f-bb8c-16af4eab4c93","type":"BasicTicker"}},"id":"523fa1d5-3e7b-452c-93e5-fdb0295571c8","type":"Grid"},{"attributes":{"plot":{"id":"00f7dec9-6357-47c0-81a2-ab301878f229","subtype":"Figure","type":"Plot"}},"id":"2bf5d42b-dc19-48af-b249-7806922dc024","type":"WheelZoomTool"},{"attributes":{"formatter":{"id":"ecb10ef9-bd48-4b17-8398-2e6968867408","type":"BasicTickFormatter"},"plot":{"id":"00f7dec9-6357-47c0-81a2-ab301878f229","subtype":"Figure","type":"Plot"},"ticker":{"id":"a669018a-94e7-479e-a986-8cae59202210","type":"BasicTicker"}},"id":"11173fbf-1aa9-42c0-a54e-222fd1b2cd93","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"d2613f38-2519-4287-93f5-cd6659cc9470","type":"PanTool"},{"id":"2bf5d42b-dc19-48af-b249-7806922dc024","type":"WheelZoomTool"},{"id":"9c717892-0409-4025-a445-b3dee265c999","type":"BoxZoomTool"},{"id":"b85ed576-e6a5-4221-8077-72b2a9cf7af8","type":"SaveTool"},{"id":"7df6af38-4fc2-4677-bc06-2e2ef32d5888","type":"ResetTool"},{"id":"0a7d92b8-20be-4859-b4a5-de03832709d0","type":"HelpTool"}]},"id":"5569e2dd-f817-46e1-979a-d2065b98dd76","type":"Toolbar"},{"attributes":{"data_source":{"id":"a164abad-b5e3-4349-9df3-9dbd85818f86","type":"ColumnDataSource"},"glyph":{"id":"e113fb1a-d96f-471f-ab5e-9c266be68d06","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"5ec051ed-4587-45b2-9f79-c060763037ea","type":"Line"},"selection_glyph":null},"id":"67aea4e7-56fc-48b7-8123-1973c297f22b","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"00f7dec9-6357-47c0-81a2-ab301878f229","subtype":"Figure","type":"Plot"}},"id":"d2613f38-2519-4287-93f5-cd6659cc9470","type":"PanTool"},{"attributes":{"overlay":{"id":"d02099e6-5fbd-4840-9bf4-af29a622caf0","type":"BoxAnnotation"},"plot":{"id":"00f7dec9-6357-47c0-81a2-ab301878f229","subtype":"Figure","type":"Plot"}},"id":"9c717892-0409-4025-a445-b3dee265c999","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"00f7dec9-6357-47c0-81a2-ab301878f229","subtype":"Figure","type":"Plot"},"ticker":{"id":"a669018a-94e7-479e-a986-8cae59202210","type":"BasicTicker"}},"id":"3a0997ce-08cc-4ba2-8a49-02dbcaf7b02f","type":"Grid"},{"attributes":{"plot":{"id":"00f7dec9-6357-47c0-81a2-ab301878f229","subtype":"Figure","type":"Plot"}},"id":"b85ed576-e6a5-4221-8077-72b2a9cf7af8","type":"SaveTool"},{"attributes":{"formatter":{"id":"57d8db9f-d6ef-49fd-bdec-33b944b8f798","type":"BasicTickFormatter"},"plot":{"id":"00f7dec9-6357-47c0-81a2-ab301878f229","subtype":"Figure","type":"Plot"},"ticker":{"id":"199b3c6f-dcf6-415f-bb8c-16af4eab4c93","type":"BasicTicker"}},"id":"94f4666b-6c71-4947-84a5-a7d1d7bdf100","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[-180.0,-176.36363636363635,-172.72727272727272,-169.09090909090907,-165.45454545454544,-161.8181818181818,- ...

# %% [markdown]
# This kind of periodic sinc function could be cyclically shifted by any angle $\varphi_\mathrm{s}$ and would not change its shape. However, we are not quite satisfied with the height of its sidelobes. It is worth to involve weights $a_m$ for the suppression of these sidelobes:
#
# \begin{equation}
#    g_\mathrm{N}(\varphi)=\sum_{m=0}^\mathrm{N}a_m\,(2-\delta_{m,0})\cos(m\varphi).
# \end{equation}
#
# The so-called in-phase weighting (see Jérôme Daniel et al 1999) is defined as
#
# \begin{equation}
#    a_m=\frac{N!^2}{(N-m)!(N+m)!}=\frac{N^\underline{m}}{N^\overline{m}},
# \end{equation}
#
# and the so-called max-$\boldsymbol{r}_\mathrm{E}$ weighting is
#
# \begin{equation}
#    a_m=\cos\Bigl(\frac{\pi}{2(\mathrm{N}+1)}\Bigr),
# \end{equation}
#
# and the neutral,rectangular weighting with $a_m=1$ is called basic.

# %%
def inphase_weights(N):
    a=np.ones(N+1)
    for n in range(1,N+1):
        a[n]=(N-n+1)/(1.0*(N+n))*a[n-1]
    return a

def maxre_weights(N):
    m=np.arange(0,N+1)
    a=np.cos(np.pi/(2*(N+1))*m)
    return a

def basic_weights(N):
    a=np.ones(N+1)
    return a

N=7
p2 = figure(title="7th-order weights",plot_width=400,plot_height=250)
m=np.arange(0,N+1)
a=basic_weights(N)
p2.line(m,a,color="green",line_width=3,legend_label="basic")
a=inphase_weights(N)
p2.line(m,a,color="red",line_width=3,legend_label="in-phase")
a=maxre_weights(N)
p2.line(m,a,color="blue",line_width=3,legend_label="max-rE")
p2.legend.background_fill_alpha=0.4
show(p2)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="2c708fff-0b7f-4885-b768-4011636bdd2f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#
type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"c87fd04d-36dd-423f-ace9-1cf80f4a706d","type":"BasicTickFormatter"},"plot":{"id":"ea6a2227-2e4d-4f0e-bdfa-b0c48190a6b7","subtype":"Figure","type":"Plot"},"ticker":{"id":"ec8c4098-facf-43be-a40f-7485167cc443","type":"BasicTicker"}},"id":"68b5ffb8-6bbd-411d-8240-18835f884326","type":"LinearAxis"},{"attributes":{"plot":{"id":"ea6a2227-2e4d-4f0e-bdfa-b0c48190a6b7","subtype":"Figure","type":"Plot"}},"id":"01702136-2e94-45e2-a9db-831fa6400855","type":"WheelZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"17f71f37-7e8b-4d6c-a50f-01069345a2c8","type":"Line"},{"attributes":{"below":[{"id":"68b5ffb8-6bbd-411d-8240-18835f884326","type":"LinearAxis"}],"left":[{" ...

# %%
def weighted_cosine_series(phi,a):
    N=a.size-1
    g=np.zeros(phi.size)
    amplitude=0;
    for m in range(0,N+1):
        g+=np.cos(m*phi)*a[m]*(2-(m==0))
        amplitude+=a[m]*(2-(m==0))
    return g/amplitude

p3 = figure(title="weighted cosine series",plot_width=400,plot_height=250)
a=basic_weights(N)
g=weighted_cosine_series(phi,a)
p3.line(phi*180/np.pi,g,line_width=3,color='green',legend_label="rectangular")
a=inphase_weights(N)
g=weighted_cosine_series(phi,a)
p3.line(phi*180/np.pi,g,line_width=3,color='red',legend_label="in-phase")
a=maxre_weights(N)
g=weighted_cosine_series(phi,a)
p3.line(phi*180/np.pi,g,line_width=3,color='blue',legend_label="max-rE")
show(p3)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="86bed1cc-de24-4696-baed-7ca511d3ecec"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#86bed1cc-de24-4696-baed-7ca511d3ecec").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("86bed1cc-de24-4696-baed-7ca511d3ecec");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '86bed1cc-de24-4696-baed-7ca511d3ecec' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e16bc5e5-713e-4660-8b38-3d7e8741356f":{"roots":{"references":[{"attributes":{"data_source":{"id":"9fe13cc0-13be-4765-b0e2-677a3acff732","type":"ColumnDataSource"},"glyph":{"id":"0073d1b4-3cfb-41ba-9e7a-ecd85959ac7a","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"1752d447-d9e5-4810-bea6-cb63b4123451","type":"Line"},"selection_glyph":null},"id":"8ddd2973-d5d2-4bc6-835d-0470cb008c3c","type":"GlyphRenderer"},{"attributes":{},"id":"52728576-6961-4705-a8fe-91448829b277","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"d6cfc385-2c27-46ab-b6b4-48a0580d87c5","type":"DataRange1d"},{"attributes":{"plot":null,"text":"weighted cosine series"},"id":"4378f4b5-30a7-4dc6-8aaa-989af7d888e4","type":"Title"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[-180.0,-176.36363636363635,-172.72727272727272,-169.09090909090907,-165.45454545454544,-161.8181818181818,-158.1818181818182,-154.54545454545453,-150.9090909090909,-147.27272727272728,-143.63636363636363,-140.0,-136.36363636363637,-132.72727272727272,-129.09090909090907,-125.45454545454545,-121.81818181818181,-118.18181818181819,-114.54545454545455,-110.9090909090909,-107.27272727272727,-103.63636363636364,-100.0,-96.36363636363636,-92.7272727272727,-89.0909090909091,-85.45454545454545,-81.81818181818181,-78.18181818181817,-74.54545454545455,-70.9090909090909,-67.27272727272727,-63.63636363636363,-59.999999999999986,-56.36363636363636,-52.727272727272705,-49.090909090909086,-45.45454545454544,-41.81818181818182,-38.181818181818166,-34.54545454545455,-30.9090909090909,-27.272727272727273,-23.636363636363626,-20.000000000000004,-16.363636363636353,-12.727272727272732,-9.090909090909083,-5.454545454545435,-1.8181818181818115,1.818181818181837,5.45454545454546,9.090909090909108,12.727272727272732,16.363636363636378,20.000000000000004,23.63636363636365,27.272727272727273,30.90909090909092,34.54545454545455,38.181818181818194,41.81818181818182,45.45454545454547,49.090909090909086,52.727272727272734,56.36363636363636,60.00000000000003,63.636363636363654,67.27272727272728,70.9090909090909,74.54545454545458,78.1818181818182,81.81818181818183,85.45454545454545,89.09090909090912,92.72727272727275,96.36363636363636,99.99999999999999,103.63636363636365,107.27272727272728,110.9090909090909,114.54545454545458,118.1818181818182,121.81818181818181,125.45454545454545,129.09090909090912,132.72727272727275,136.36363636363637,140.0,143.63636363636368,147.27272727272728,150.9090909090909,154.54545454545453,158.18181818181822,161.81818181818184,165.45454545454544,169.09090909090915,172.72727272727278,176.36363636363637,180.0],"y":[-0.06666666666666667,-0.059285544335857844,-0.038748473852165025,-0.009530812140197594,0.02198137516526907,0.048862705760299226,0.06514342479172198,0.06711084081189486,0.054138757120002594,0.028863509125865296,-0.0033388318646346395,-0.03547259241586391,-0.060410928534776386,-0.07244207200557028,-0.06854510628500132,-0.04911750800340576,-0.01798623742228749,0.018318841745476436,0.051895630222310286,0.0751401665772346,0.08241307091320942,0.07134832141811476,0.04351357631107595,0.004256378689420807,-0.0382658998223121,-0.07470479780233909,-0.09647900535471794,-0.09767908644574642,-0.07651848670589126,-0.03600426372121667,0.016356422496370933,0.06981234867749281,0.11239156720853102,0.1333333333333334,0.12546967142867324,0.08708256721027109,0.02283898171210906,-0.056437960356583945,-0.13519416820985572,-0.1955746371248441,-0.2204695891229172,-0.19665549467639412,-0.11746886344003855,0.015488400605068323,0.19195901610478766,0.3940809653854625,0.598753813193246,0.7809618829982158,0.9175204803593677,0.9906276436111278,0.9906276436111274,0.917520480359367,0.7809618829982147,0.598753813193246,0.39408096538546095,0.19195901610478766,0.015488400605067242,-0.11746886344003855,-0.19665549467639448,-0.2204695891229172,-0.19557463712484377,-0.13519416820985572,-0.0564379603565834,0.02283898171210906,0.08708256721027152,0.12 ...

# %%
def g_ambipan(N,phis,phi,weight_type):
    g=np.zeros(phi.size)
    ampl=0
    if weight_type == 1:
        a=inphase_weights(N)
    elif weight_type == 2:
        a=maxre_weights(N)
    else:
        a=basic_weights(N)
    g=weighted_cosine_series(phi-phis,a)
    return g

# %%
output_notebook()
g=g_ambipan(5,0,phi,0)
p = figure(title="2D Ambi Panning Function",plot_width=400, plot_height=270, x_range=(-180,180), y_range=(-.4,1.1))
ll=p.line(phi*180/np.pi, g , line_width=3)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0453b373-e389-4063-b373-70ecea37b242">Loading BokehJS ...</span>
#     </div>

# %%
def plot_ambipan(N,phis,weight_type):
    phi=np.linspace(-np.pi,np.pi,100)
    g=g_ambipan(N,phis*np.pi/180,phi,weight_type)
    ll.data_source.data['y']=g
    push_notebook()

# %%
show(p,notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="5f3ca5a8-e35b-483c-a60b-9eeaae35956f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#5f3ca5a8-e35b-483c-a60b-9eeaae35956f").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("559fc079-d1d4-4d0b-9713-7986ca8cffa5", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5f3ca5a8-e35b-483c-a60b-9eeaae35956f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5f3ca5a8-e35b-483c-a60b-9eeaae35956f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"445cdddb-690e-494f-bb7f-050c2416f572":{"roots":{"references":[{"attributes":{},"id":"b126eb76-6ce0-49ac-87fd-db1f0a4575f4","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"ba5691b3-d071-44da-8b6c-5b7dd0a092a7","subtype":"Figure","type":"Plot"},"ticker":{"id":"b